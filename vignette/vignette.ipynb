# %% [markdown]
# # Spellcheck Colab Markdown
#
# Right now I just want to use this for testing. For example, will our extension catch different nesting structures:
#
# 1. spellcheck this
#   1. and this
#   1. sublist missspell
# 1. asdf
#
# and
#
# * spellcheck
# * garbo
#   1. different nesting
#   1. structrs
# * items
#
# ```
# I am not sure if we want to spell check tabbed code-style content?
# ```

# %% [markdown]
# We should also check
#
# # Titles misspl
# ## Headers errror
# ### Subheaders tpo
# #### Sub-subheaders mstake
#
#
#
# As well as *italic misteaks* and _italic season twoo mistakes_ and **bold typoos** __bold seson two typos__.

# %%
import numpy as np
import time

# don't spellcheck me I'm coooode

# %% [markdown]
# Other markdown situations include horizontal lines
#
# ---
#
# as well as tables
#
# | Name | Occupation
# |---|---
# | Josiah | DJ
#
#
# Any HTML markdown
#
# <center>Caption</center>
#
# Links [to othr websits](https://www.google.com/).
#
# LaTeX $\phi \omega \mu \tau \alpha$.
